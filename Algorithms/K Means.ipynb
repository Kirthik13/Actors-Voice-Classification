# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

df = pd.read_csv('Actor_feature.csv')

x = df.iloc[:,1:41]
y = df['Actor']

kmeans = KMeans(10)
kmeans.fit(x)
# Out:
# KMeans(n_clusters=10)

# %%
identified_clusters = kmeans.fit_predict(x)
identified_clusters
# Out:
# array([3, 8, 8, ..., 6, 6, 6])

# %%
data_with_clusters=df.copy()
data_with_clusters['Clusters'] = identified_clusters

plt.scatter(data_with_clusters.iloc[:,0:1],data_with_clusters['Actor'],c=data_with_clusters['Clusters'],cmap='rainbow')

# %%
kmeans.predict(df.iloc[0:5,1:41])
# Out:
# array([3, 8, 8, 8, 3])

# %%
kmeans.predict(df.iloc[3000:3010,1:41])
# Out:
# array([8, 8, 0, 0, 0, 8, 0, 8, 8, 8])
